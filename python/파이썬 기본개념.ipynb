# %%
# 유용한 메소드 & 팁 정리
'''

자주 사용하는 내장함수:
sum, max, min, len, sort or sorted(data), a.reverse() - 리스트에서만, .zfill(n): n자리만큼 0채움

'''

# %%
# 모듈 정리
'''
import datetime -> datatime.now(), datatime,timedelta(특정날짜), .strftime("%H:%M:%S"), datatime.strptime(name, str문자열을 시간으로)

import time -> time.sleep(멈춤)

import os -> os.getcwd():현재경로, os.rename(before, after)

import numpy -> numpy.arange(0, 5, 0.1):

import random -> random.randint(0, n): 0~n까지 중 랜덤
'''

# %%
# 파일 확장자 확인 endswith()

file_list = ['name1.xlsx','name2.xlsx','name3.jpg','name4.ppt']
xlsx_list=[ i for i in file_list if i.endswith(('xlsx','ppt')) ] # 2개 이상일 때는 괄호로 묶어주기
print(xlsx_list)

# for i in file_list:
#     if i.endswith('xlsx'):
#         xlsx_list.append(i)
# Out:
# ['name1.xlsx', 'name2.xlsx', 'name4.ppt']

# %%
# del로 원소 삭제할 때 하나의 값이 삭제되면 새로 인덱싱 된다.

# 스플릿, 배트맨 삭제
movie_rank = ['닥터 스트레인지', '슈퍼맨', '스플릿', '배트맨']
del movie_rank[2]
del movie_rank[2]
print(movie_rank)
# Out:
# ['닥터 스트레인지', '슈퍼맨']

# %%
# join으로 리스트의 모든 데이터 합치기

interest = ['삼성전자', 'LG전자', 'Naver', 'SK하이닉스', '미래에셋대우']
print("/".join(interest))
# Out:
# 삼성전자/LG전자/Naver/SK하이닉스/미래에셋대우

# %%
# 여러 데이터를 그냥 입력하면 자동으로 tuple로 지정
# tuple 내부 값은 변경 x

t = 1,2,3,4
print(t)

# 튜플 언팩킹
a,b,c,d = t 
print(a, b, c, d)
# Out:
# (1, 2, 3, 4)
# 1 2 3 4

# %%
#star expression: 변수의 갯수가 정해지지 않고, 리스트로 묶임

a, b, *c = 0, 1, 2, 3, 4, 5
print(c)
# Out:
# [2, 3, 4, 5]

# %%
# 딕셔너리

ice = {'메로나': 1000,
       '폴로포': 1200,
       '빵빠레': 1800,
       '죠스바': 1200,
       '월드콘': 1500}

#삭제방법1
ice.pop('메로나')
print(ice)

#삭제방법2
# ice.popitem() --> 제일 뒤에 값 삭제

#삭제방법3
del ice['빵빠레']
print(ice)

# 딕셔너리 합치기
new_product = {'팥빙수':2700, '아맛나':1000}
ice.update(new_product)
print(ice)

# zip
keys = ("apple", "pear", "peach")
vals = (300, 250, 400)
result = dict(zip(keys, vals))
print(result)
# Out:
# {'폴로포': 1200, '빵빠레': 1800, '죠스바': 1200, '월드콘': 1500}
# {'폴로포': 1200, '죠스바': 1200, '월드콘': 1500}

# %%
import requests
btc = requests.get("https://api.bithumb.com/public/ticker/").json()['data']

print(btc)
# Out:
# {'opening_price': '53157000', 'closing_price': '52670000', 'min_price': '52267000', 'max_price': '53849000', 'units_traded': '1864.6419893', 'acc_trade_value': '98570964758.5548', 'prev_closing_price': '53163000', 'units_traded_24H': '2218.884585', 'acc_trade_value_24H': '117385340135.7078', 'fluctate_24H': '-526000', 'fluctate_rate_24H': '-0.99', 'date': '1649666526149'}

# %%
# enumerate

price_list = [32100, 32150, 32000, 32500]
for i, data in enumerate(price_list, start = 1):
    print(i, data)
# Out:
# 1 32100
# 2 32150
# 3 32000
# 4 32500

# %%
#이중배열 출력

apart = [ [101, 102], [201, 202], [301, 302] ]

for i in apart:
    for j in i:
        print(j)
print('')
for i in apart[::-1]:
    for j in i[::-1]:
        print(j)

print('')
for x,y in apart: #이중 for문 사용x
    print(x)
    print(y)

# %%
#for문으로 이중배열 생성

data = [
    [ 2000,  3050,  2050,  1980],
    [ 7500,  2050,  2050,  1980],
    [15450, 15050, 15550, 14900]
]


result = []
for line in data:
    sub = []
    for column in line:
        sub.append(column * 1.00014)
    result.append(sub)
print(result)
# Out:
# [[2000.28, 3050.427, 2050.2870000000003, 1980.2772], [7501.05, 2050.2870000000003, 2050.2870000000003, 1980.2772], [15452.163, 15052.107, 15552.177, 14902.086000000001]]

# %%
import random


class Account:
    # class variable
    account_count = 0

    def __init__(self, name, balance):
        self.deposit_count = 0
        self.deposit_log = []
        self.withdraw_log = []

        self.name = name
        self.balance = balance
        self.bank = "SC은행"

        # 3-2-6
        num1 = random.randint(0, 999)
        num2 = random.randint(0, 99)
        num3 = random.randint(0, 999999)

        num1 = str(num1).zfill(3)  # 1 -> '1' -> '001'
        num2 = str(num2).zfill(2)  # 1 -> '1' -> '01'
        num3 = str(num3).zfill(6)  # 1 -> '1' -> '0000001'
        self.account_number = num1 + '-' + num2 + '-' + num3  # 001-01-000001
        Account.account_count += 1

    @classmethod
    def get_account_num(cls):
        print(cls.account_count)  # Account.account_count

    def deposit(self, amount):
        if amount >= 1:
            self.deposit_log.append(amount)
            self.balance += amount

            self.deposit_count += 1
            if self.deposit_count % 5 == 0:         # 5, 10, 15
                # 이자 지금
                self.balance = (self.balance * 1.01)


    def withdraw(self, amount):
        if self.balance > amount:
            self.withdraw_log.append(amount)
            self.balance -= amount

    def display_info(self):
        print("은행이름: ", self.bank)
        print("예금주: ", self.name)
        print("계좌번호: ", self.account_number)
        print("잔고: ", self.balance)

    def withdraw_history(self):
        for amount in self.withdraw_log:
            print(amount)

    def deposit_history(self):
        print(self.deposit_log)


k = Account("Kim", 1000)
k.deposit(100)
k.deposit(200)
k.deposit(300)
k.deposit_history()

k.withdraw(100)
k.withdraw(200)
k.withdraw_history()
# Out:
# [100, 200, 300]
# 100
# 200

# %%
class 차:

    def __init__(self, 바퀴, 가격):
        self.바퀴 = 바퀴
        self.가격 = 가격

    def 정보(self):
        print(f"바퀴수 {self.바퀴}")
        print(f"가격 {self.가격}")
    
# '차'클래스 상속
class 자전차(차):
    def __init__(self, 바퀴, 가격, 구동계):
        super().__init__(바퀴, 가격)    # 슈퍼클래스로
        self.구동계 = 구동계

    def 정보(self):
        super().정보()
        print(f"구동계 {self.구동계}")

class 자동차(차):
    def __init__(self, 바퀴, 가격):
        super().__init__(바퀴, 가격)


bicycle = 자전차(2, 100, "시마노")
bicycle.정보()
# Out:
# 바퀴수 2
# 가격 100
# 구동계 시마노

# %%
per = ["10.31", "", "8.00"]

for i in per:
    try:
        print(float(i))
    except:
        print(0)
    else:
        print("clean data")
    finally:
        print("변환 완료")
# Out:
# 10.31
# clean data
# 변환 완료
# 0
# 변환 완료
# 8.0
# clean data
# 변환 완료
